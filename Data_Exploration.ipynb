# %% [markdown]
# # Data exploration and Data Visualization

# %% [markdown]
# ### Import all necessary libraries

# %%
import cv2
import os
import csv  
import math
import random
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get the names of all classes/categories inside the dataset directory.

# %%
all_classes_names = os.listdir('GMS')

# %% [markdown]
# ### Visualize a random sample videos from the dataset for each category

# %%
random_range = random.sample(range(len(all_classes_names)), 3)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):
    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'GMS/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'GMS/{selected_class_Name}/{selected_video_file_name}')

    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    # Release the VideoCapture object.
    video_reader.release()

    # Convert the frame from BGR into RGB format.
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.figure(figsize=(15, 15))
    plt.subplot(3, 1, counter);
    plt.imshow(rgb_frame);
    plt.axis('off')

# %% [markdown]
# ### Create a csv file for collecting all the category information

# %%
header = ['video_name', 'fps', 'height', 'width', 'duration', 'frame_count']
with open('dataset.csv', 'w', encoding='UTF8') as f:
    dataset_writer = csv.writer(f)
    # write the header
    dataset_writer.writerow(header)

# %% [markdown]
# ### Create a csv file for collecting information from "bridge connecting" category

# %%
header = ['video_name', 'fps', 'height', 'width', 'duration', 'frame_count']
with open('bridge_connecting.csv', 'w', encoding='UTF8') as f:
    bridgr_writer = csv.writer(f)
    # write the header
    bridgr_writer.writerow(header)

# %% [markdown]
# ### Create a csv file for collecting information from "baggage handling" category

# %%
header = ['video_name', 'fps', 'height', 'width', 'duration', 'frame_count']
with open('baggage_handling.csv', 'w', encoding='UTF8') as f:
    baggage_writer = csv.writer(f)
    # write the header
    baggage_writer.writerow(header)

# %% [markdown]
# ### Create a csv file for collecting information from "misclaneous" category

# %%
header = ['video_name', 'fps', 'height', 'width', 'duration', 'frame_count']
with open('misclaneous.csv', 'w', encoding='UTF8') as f:
    baggage_writer = csv.writer(f)
    # write the header
    baggage_writer.writerow(header)

# %% [markdown]
# ### Extract information from bridge connecting dataset and write it to corresponding csv file

# %%
folder = os.path.join(os.getcwd(), r'GMS\bridge_connecting')

for count, filename in enumerate(os.listdir(folder)):
    video_path = os.path.join(folder, filename)
    cap = cv2.VideoCapture(video_path)
    
    # Properties
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    fps = round(cap.get(cv2.CAP_PROP_FPS),2)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = math.floor((frame_count/fps))
    
    data = [filename, fps, height, width, duration, frame_count]

    with open('dataset.csv', 'a', encoding='UTF8') as f:
        dataset_writer = csv.writer(f)
        # write the data
        dataset_writer.writerow(data)
        
    with open('bridge_connecting.csv', 'a', encoding='UTF8') as f:
        bridgr_writer = csv.writer(f)
        # write the data
        bridgr_writer.writerow(data)
    
    print(f"Video name:{filename}\tFPS:{fps}\t Height:{height}\tWidth:{width}\tDuration:{duration}\tFramecount:{frame_count}")

# Close down everything
cap.release()
cv2.destroyAllWindows()
# Out:
# Video name:vid_1.mp4	FPS:29.97	 Height:720	Width:1280	Duration:3	Framecount:107
# Video name:vid_10.mp4	FPS:25.0	 Height:720	Width:1280	Duration:50	Framecount:1257
# Video name:vid_100.mp4	FPS:30.0	 Height:720	Width:1280	Duration:52	Framecount:1561
# Video name:vid_101.mp4	FPS:6.68	 Height:720	Width:1280	Duration:4	Framecount:28
# Video name:vid_102.mp4	FPS:25.0	 Height:360	Width:480	Duration:22	Framecount:565
# Video name:vid_103.mp4	FPS:25.0	 Height:720	Width:1280	Duration:4	Framecount:113
# Video name:vid_104.mp4	FPS:24.0	 Height:720	Width:1280	Duration:50	Framecount:1201
# Video name:vid_105.mp4	FPS:29.59	 Height:1080	Width:608	Duration:9	Framecount:267
# Video name:vid_106.mp4	FPS:30.0	 Height:720	Width:1280	Duration:95	Framecount:2851
# Video name:vid_107.mp4	FPS:30.0	 Height:720	Width:720	Duration:50	Framecount:1501
# Video name:vid_108.mp4	FPS:15.0	 Height:360	Width:480	Duration:91	Framecount:1365
# ...

# %% [markdown]
# ### Extract information from baggage handling dataset and write it to corresponding csv file

# %%
folder = os.path.join(os.getcwd(), r'GMS\baggage_handling')

for count, filename in enumerate(os.listdir(folder)):
    video_path = os.path.join(folder, filename)
    cap = cv2.VideoCapture(video_path)
    
    # Properties
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    fps = round(cap.get(cv2.CAP_PROP_FPS),2)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = math.floor((frame_count/fps))
    
    data = [filename, fps, height, width, duration, frame_count]
    
    with open('dataset.csv', 'a', encoding='UTF8') as f:
        dataset_writer = csv.writer(f)
        # write the data
        dataset_writer.writerow(data)
        
    with open('baggage_handling.csv', 'a', encoding='UTF8') as f:
        baggage_writer = csv.writer(f)
        # write the data
        baggage_writer.writerow(data)
        
    print(f"Video name:{filename}\tFPS:{fps}\t Height:{height}\tWidth:{width}\tDuration:{duration}\tFramecount:{frame_count}")

# Close down everything
cap.release()
cv2.destroyAllWindows()
# Out:
# Video name:vid_1.mp4	FPS:25.0	 Height:720	Width:1280	Duration:3	Framecount:76
# Video name:vid_10.mp4	FPS:29.97	 Height:720	Width:1280	Duration:5	Framecount:151
# Video name:vid_100.mp4	FPS:30.0	 Height:720	Width:1280	Duration:7	Framecount:211
# Video name:vid_101.mp4	FPS:30.0	 Height:720	Width:1280	Duration:7	Framecount:227
# Video name:vid_102.mp4	FPS:30.0	 Height:720	Width:1280	Duration:8	Framecount:257
# Video name:vid_103.mp4	FPS:30.0	 Height:720	Width:1280	Duration:9	Framecount:287
# Video name:vid_104.mp4	FPS:30.0	 Height:720	Width:1280	Duration:5	Framecount:153
# Video name:vid_105.mp4	FPS:30.0	 Height:720	Width:1280	Duration:6	Framecount:183
# Video name:vid_106.mp4	FPS:30.0	 Height:720	Width:1280	Duration:6	Framecount:199
# Video name:vid_107.mp4	FPS:30.0	 Height:720	Width:1280	Duration:7	Framecount:229
# Video name:vid_108.mp4	FPS:30.0	 Height:720	Width:1280	Duration:8	Framecount:259
# Video name:vid_109.mp4	FPS:30.0	 Height:720	Width:1280	Duration:9	Framecount:275
# ...

# %% [markdown]
# ### Extract information from misclaneous dataset and write it to corresponding csv file

# %%
folder = os.path.join(os.getcwd(), r'GMS\misclaneous')

for count, filename in enumerate(os.listdir(folder)):
    video_path = os.path.join(folder, filename)
    cap = cv2.VideoCapture(video_path)
    
    # Properties
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    fps = round(cap.get(cv2.CAP_PROP_FPS),2)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = math.floor((frame_count/fps))
    
    data = [filename, fps, height, width, duration, frame_count]
    
    with open('dataset.csv', 'a', encoding='UTF8') as f:
        dataset_writer = csv.writer(f)
        # write the data
        dataset_writer.writerow(data)
        
    with open('misclaneous.csv', 'a', encoding='UTF8') as f:
        baggage_writer = csv.writer(f)
        # write the data
        baggage_writer.writerow(data)
        
    print(f"Video name:{filename}\tFPS:{fps}\t Height:{height}\tWidth:{width}\tDuration:{duration}\tFramecount:{frame_count}")

# Close down everything
cap.release()
cv2.destroyAllWindows()
# Out:
# Video name:vid_1.mp4	FPS:25.0	 Height:720	Width:1280	Duration:25	Framecount:626
# Video name:vid_10.mp4	FPS:25.0	 Height:720	Width:1280	Duration:36	Framecount:918
# Video name:vid_100.mp4	FPS:25.0	 Height:720	Width:1280	Duration:27	Framecount:676
# Video name:vid_101.mp4	FPS:25.0	 Height:720	Width:1280	Duration:37	Framecount:936
# Video name:vid_102.mp4	FPS:25.0	 Height:720	Width:1280	Duration:46	Framecount:1165
# Video name:vid_103.mp4	FPS:25.0	 Height:720	Width:1280	Duration:40	Framecount:1013
# Video name:vid_104.mp4	FPS:25.0	 Height:720	Width:1280	Duration:39	Framecount:989
# Video name:vid_105.mp4	FPS:25.0	 Height:720	Width:1280	Duration:19	Framecount:493
# Video name:vid_106.mp4	FPS:25.0	 Height:720	Width:1280	Duration:55	Framecount:1381
# Video name:vid_107.mp4	FPS:25.0	 Height:720	Width:1280	Duration:42	Framecount:1051
# Video name:vid_108.mp4	FPS:25.0	 Height:720	Width:1280	Duration:41	Framecount:1027
# ...

# %% [markdown]
# ### Read the "dataset" csv file

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#       video_name    fps  height  width  duration  frame_count
# 0      vid_1.mp4  29.97     720   1280         3          107
# 1     vid_10.mp4  25.00     720   1280        50         1257
# 2    vid_100.mp4  30.00     720   1280        52         1561
# 3    vid_101.mp4   6.68     720   1280         4           28
# 4    vid_102.mp4  25.00     360    480        22          565
# ..           ...    ...     ...    ...       ...          ...
# 385   vid_95.mp4  25.00     720   1280        32          818
# 386   vid_96.mp4  25.00     720   1280        33          843
# 387   vid_97.mp4  25.00     720   1280        43         1093
# 388   vid_98.mp4  25.00     720   1280        32          818
# 389   vid_99.mp4  25.00     720   1280        34          868
#
# [390 rows x 6 columns]

# %% [markdown]
# ### Statistical data of the dataset

# %%
df.describe()
# Out:
#               fps      height        width    duration  frame_count
# count  390.000000   390.00000   390.000000  390.000000   390.000000
# mean    27.373513   713.00000  1154.589744   29.735897   812.858974
# std      3.062411   146.78146   278.504177   26.986800   753.435353
# min      6.000000   320.00000   360.000000    1.000000    28.000000
# 25%     25.000000   720.00000  1280.000000    8.000000   240.000000
# 50%     29.725000   720.00000  1280.000000   23.000000   616.500000
# 75%     30.000000   720.00000  1280.000000   44.000000  1145.500000
# max     30.010000  1080.00000  1280.000000  159.000000  4772.000000

# %% [markdown]
# ### Read the bridge connecting dataset csv file

# %%
bridge_df = pd.read_csv('bridge_connecting.csv')
bridge_df
# Out:
#       video_name    fps  height  width  duration  frame_count
# 0      vid_1.mp4  29.97     720   1280         3          107
# 1     vid_10.mp4  25.00     720   1280        50         1257
# 2    vid_100.mp4  30.00     720   1280        52         1561
# 3    vid_101.mp4   6.68     720   1280         4           28
# 4    vid_102.mp4  25.00     360    480        22          565
# ..           ...    ...     ...    ...       ...          ...
# 125   vid_95.mp4  25.00     720   1280         8          222
# 126   vid_96.mp4  25.00     360    640        12          305
# 127   vid_97.mp4  25.00     360    640        10          270
# 128   vid_98.mp4  25.00     360    640        14          350
# 129   vid_99.mp4  30.00     720   1280         9          291
#
# [130 rows x 6 columns]

# %% [markdown]
# ### Statistical data of bridge connecting dataset

# %%
bridge_df.describe()
# Out:
#               fps       height        width    duration  frame_count
# count  130.000000   130.000000   130.000000  130.000000   130.000000
# mean    28.242538   740.538462  1065.153846   38.561538  1118.284615
# std      3.727888   198.935117   320.593719   34.527375  1016.560146
# min      6.000000   320.000000   480.000000    1.000000    28.000000
# 25%     25.000000   720.000000   615.500000    9.250000   271.000000
# 50%     29.970000   720.000000  1280.000000   28.000000   844.000000
# 75%     30.000000   720.000000  1280.000000   57.750000  1711.750000
# max     30.010000  1080.000000  1280.000000  159.000000  4772.000000

# %% [markdown]
# ### Read the baggage handling dataset csv file

# %%
baggage_df = pd.read_csv('baggage_handling.csv')
baggage_df
# Out:
#       video_name    fps  height  width  duration  frame_count
# 0      vid_1.mp4  25.00     720   1280         3           76
# 1     vid_10.mp4  29.97     720   1280         5          151
# 2    vid_100.mp4  30.00     720   1280         7          211
# 3    vid_101.mp4  30.00     720   1280         7          227
# 4    vid_102.mp4  30.00     720   1280         8          257
# ..           ...    ...     ...    ...       ...          ...
# 125   vid_95.mp4  30.00     720   1280        12          361
# 126   vid_96.mp4  30.00     720   1280         4          144
# 127   vid_97.mp4  30.00     720   1280         6          181
# 128   vid_98.mp4  30.00     720   1280         6          201
# 129   vid_99.mp4  30.00     720   1280         6          181
#
# [130 rows x 6 columns]

# %% [markdown]
# ### Statistical data of baggage handling dataset

# %%
baggage_df.describe()
# Out:
#               fps       height        width    duration  frame_count
# count  130.000000   130.000000   130.000000  130.000000   130.000000
# mean    28.839769   678.461538  1118.615385    7.569231   230.930769
# std      2.402058   152.896893   325.424836    3.501801   108.700370
# min     15.030000   360.000000   360.000000    1.000000    30.000000
# 25%     29.970000   720.000000  1280.000000    5.000000   151.000000
# 50%     30.000000   720.000000  1280.000000    7.000000   216.500000
# 75%     30.000000   720.000000  1280.000000   10.000000   300.750000
# max     30.000000  1080.000000  1280.000000   15.000000   451.000000

# %% [markdown]
# ### Read the misclaneous dataset csv file

# %%
misclaneous_df = pd.read_csv('misclaneous.csv')
misclaneous_df
# Out:
#       video_name   fps  height  width  duration  frame_count
# 0      vid_1.mp4  25.0     720   1280        25          626
# 1     vid_10.mp4  25.0     720   1280        36          918
# 2    vid_100.mp4  25.0     720   1280        27          676
# 3    vid_101.mp4  25.0     720   1280        37          936
# 4    vid_102.mp4  25.0     720   1280        46         1165
# ..           ...   ...     ...    ...       ...          ...
# 125   vid_95.mp4  25.0     720   1280        32          818
# 126   vid_96.mp4  25.0     720   1280        33          843
# 127   vid_97.mp4  25.0     720   1280        43         1093
# 128   vid_98.mp4  25.0     720   1280        32          818
# 129   vid_99.mp4  25.0     720   1280        34          868
#
# [130 rows x 6 columns]

# %% [markdown]
# ### Statistical data of misclaneous dataset

# %%
misclaneous_df.describe()
# Out:
#               fps  height   width    duration  frame_count
# count  130.000000   130.0   130.0  130.000000   130.000000
# mean    25.038231   720.0  1280.0   43.076923  1089.361538
# std      0.435898     0.0     0.0   15.450654   392.766278
# min     25.000000   720.0  1280.0   12.000000   301.000000
# 25%     25.000000   720.0  1280.0   33.000000   843.250000
# 50%     25.000000   720.0  1280.0   40.000000  1012.000000
# 75%     25.000000   720.0  1280.0   49.000000  1241.750000
# max     29.970000   720.0  1280.0  109.000000  2736.000000

# %% [markdown]
# ### Duration distribution for bridge connecting dataset

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot(bridge_df['duration'])

plt.xlabel("Jet Bridge Connecting")
plt.ylabel("Video Duration")
plt.title("Video Duration Distribution in box plot")

# show plot
plt.show()

# %% [markdown]
# ### Duration distribution for baggage handling dataset

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot(baggage_df['duration'])

plt.xlabel("Baggage Handling")
plt.ylabel("Video Duration")
plt.title("Video Duration Distribution in box plot")

# show plot
plt.show()

# %% [markdown]
# ### Duration distribution of bridge connecting dataset

# %%
# Creating dataset
data = [bridge_df['duration']]
 
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#0000FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    
# x-axis labels
ax.set_yticklabels(['Jet Bridge Connecting'])
 
# Adding title
plt.title("Video Duration Distribution")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# %% [markdown]
# ### Duration distribution of baggage handling dataset

# %%
# Creating dataset
data = [baggage_df['duration']]
 
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#00FF00']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    
# x-axis labels
ax.set_yticklabels(['Baggage Handling'])
 
# Adding title
plt.title("Video Duration Distribution")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# %% [markdown]
# ### Duration distribution of misclaneous dataset

# %%
# Creating dataset
data = [misclaneous_df['duration']]
 
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#FF0000']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    
# x-axis labels
ax.set_yticklabels(['misclaneous'])
 
# Adding title
plt.title("Video Duration Distribution")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# %% [markdown]
# ### Duration distribution of the overall dataset

# %%
# Creating dataset
data = [bridge_df['duration'], baggage_df['duration'], misclaneous_df['duration']]
 
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True, notch ='True', vert = 0)
 
colors = ['#0000FF','#00FF00', '#FF0000']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    
# x-axis labels
ax.set_yticklabels(['Jet Bridge Connecting', 'Baggage Handling', 'misclaneous'])
 
# Adding title
plt.title("Video Duration Distribution")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()
